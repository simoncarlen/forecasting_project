# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import meteorological_temporal_data as metdata
import seaborn as sns

tex_fonts = {
    "text.usetex": True,
    "font.family": "serif",
    "axes.labelsize": 10,
    "font.size": 10,
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
    }
plt.rcParams.update(tex_fonts)

# %%
df_weather = metdata.clean_weather_data(path='../air_weather_data/')

# %%
df_weather['Atmospheric pressure'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_weather = metdata.interpolate_weather(df_weather)

# %%
df_weather['Atmospheric pressure'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_weather = metdata.add_sine_cosine(df_weather)

# %%
from os import major

fig, ax = plt.subplots(constrained_layout = True, figsize = (3.5, 2))
df_weather['2016-01-31 00:00:00':'2016-02-01 00:00:00'][['Sine day', 'Cosine day']].plot(ax=ax)
ax.set_xlabel('')
plt.legend(loc='lower right', bbox_to_anchor= (1.0, 1.025), ncol=1, borderaxespad=0.1)
# ax.set_xticks([], minor=True)
# plt.savefig('../plots/time_signals.pdf')

# %%
# df_weather.to_csv('../air_weather_data/metdata.csv')

# %%
fig, axes = plt.subplots(3, 2, constrained_layout = True, figsize = (8,5))
annots = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)', '(i)', '(j)']

j = 0
for i, ax in enumerate(fig.axes):
    ax.hist(df_weather.iloc[:, j], edgecolor='black', label=df_weather.columns[i]) # linewidth default = 1.5
    ax.legend(loc='lower right', bbox_to_anchor= (1.0, 1.025), ncol=2, borderaxespad=0.1)
    # ax.legend(loc='lower right', bbox_to_anchor= (1.0, 1.025), ncol=2, borderaxespad=0.1)
    # ax.annotate(annots[i], xy=(0.0, 1.09), xycoords="axes fraction")
    ax.set_xlabel('')
    j += 1
